# %% [markdown]
# ## Mini prject 5: Enhancing Text Classification in Information Retrieval: A Comprehensive Approach with TF-IDF, Naive Bayes, Word Embeddings, LSA, and SVM

# %% [markdown]
# In this section we import needed libraries.

# %%
import pandas as pd
import numpy as np 
import math 
from numpy import linalg as LA

from nltk.tokenize import regexp_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
import string

import matplotlib.pyplot as plt 
import gensim
from sklearn.svm import SVC
from gensim.models import Word2Vec
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from nltk.tokenize import word_tokenize

# %%
# Read data from dataset and store
train_pos_df = pd.read_csv("data/train_pos.csv")
train_neg_df = pd.read_csv("data/train_neg.csv")
test_pos_df  = pd.read_csv("data/test_pos.csv")
test_neg_df  = pd.read_csv("data/test_neg.csv")

# %%
# delete index column in data frames
train_pos_df.drop(train_pos_df.columns[0], axis=1, inplace=True)
train_neg_df.drop(train_neg_df.columns[0], axis=1, inplace=True)
test_pos_df.drop(test_pos_df.columns[0], axis=1, inplace=True)
test_neg_df.drop(test_neg_df.columns[0], axis=1, inplace=True)

# %% [markdown]
# Now, let's see what are the data frames look like!

# %%
train_pos_df.head()
# Out:
#       ID                                               text  rating
# 0      0  Bromwell High is a cartoon comedy. It ran at t...       9
# 1  10000  Homelessness (or Houselessness as George Carli...       8
# 2  10001  Brilliant over-acting by Lesley Ann Warren. Be...      10
# 3  10002  This is easily the most underrated film inn th...       7
# 4  10003  This is not the typical Mel Brooks film. It wa...       8

# %%
train_neg_df.head()
# Out:
#       ID                                               text  rating
# 0      0  Story of a man who has unnatural feelings for ...       3
# 1  10000  Airport '77 starts as a brand new luxury 747 p...       4
# 2  10001  This film lacked something I couldn't put my f...       4
# 3  10002  Sorry everyone,,, I know this is supposed to b...       1
# 4  10003  When I was little my parents took me along to ...       1

# %%
test_pos_df.head()
# Out:
#       ID                                               text  rating
# 0      0  I went and saw this movie last night after bei...      10
# 1  10000  Actor turned director Bill Paxton follows up h...       7
# 2  10001  As a recreational golfer with some knowledge o...       9
# 3  10002  I saw this film in a sneak preview, and it is ...       8
# 4  10003  Bill Paxton has taken the true story of the 19...       8

# %%
test_neg_df.head()
# Out:
#       ID                                               text  rating
# 0      0  Once again Mr. Costner has dragged out a movie...       2
# 1  10000  This is an example of why the majority of acti...       4
# 2  10001  First of all I hate those moronic rappers, who...       1
# 3  10002  Not even the Beatles could write songs everyon...       3
# 4  10003  Brass pictures (movies is not a fitting word f...       3

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Define a function to do the data preprocessing which does the following tasks:
# <ul>
#     <li>Tokenization</li><br>
#     <li>Delete stop words</li><br>
#     <li>Lowercase words</li><br>
#     <li>Delete punctuations</li><br>
#     <li>Stemming</li><br>
#
# </ul>

# %%
def preprocessing(document):
    '''
    Define a regular expression pattern for tokenization 
    (matching words, 3-digit numbers, numbers with more than 3 digits and 
    have thousands seperators in which n > 3, and floating-point numbers)
    '''
    if document is not None:
        pattern = r'\d{1,3}(?:,\d{3})*(?:\.\d+)?|\w+'

        # Tokenize the text using the regular expression pattern    
        tokens = regexp_tokenize(document, pattern)

        # Lowercase the tokens
        tokens = [word.lower() for word in tokens if word.isalpha()]


        # Get the set of English stopwords
        stop_words = set(stopwords.words('english'))

        # Remove stopwords
        tokens = [word for word in tokens if word not in stop_words]

        # Remove punctuation
        tokens = [word for word in tokens if word not in string.punctuation]

        # Stemming
        stemmer = PorterStemmer()
        tokens = [stemmer.stem(word) for word in tokens]

        # return the processed document
        return ' '.join(tokens)
    else:
        return ''

# %% [markdown]
# ##### Document preprocessing
# In this section we want to do preprocessing on data and store the processed text in 'preprocessed' column of every data frame.

# %% [markdown]
# Train data preproccessing here

# %%
# Apply the preprocessing function to the 'text' column
# and make a new column named preprocessed to store the 
# text which is preprocessed for each df
train_pos_df['preprocessed'] = train_pos_df['text'].apply(preprocessing)
train_neg_df['preprocessed'] = train_neg_df['text'].apply(preprocessing)
test_pos_df['preprocessed']  = test_pos_df['text'].apply(preprocessing)
test_neg_df['preprocessed']  = test_neg_df['text'].apply(preprocessing)

# %% [markdown]
# Now, look what is the new shape of positive class data frame as an example!

# %%
train_pos_df.head()
# Out:
#       ID                                               text  rating  \
# 0      0  Bromwell High is a cartoon comedy. It ran at t...       9
# 1  10000  Homelessness (or Houselessness as George Carli...       8
# 2  10001  Brilliant over-acting by Lesley Ann Warren. Be...      10
# 3  10002  This is easily the most underrated film inn th...       7
# 4  10003  This is not the typical Mel Brooks film. It wa...       8
#
#                                         preprocessed
# 0  bromwel high cartoon comedi ran time program s...
# 1  homeless houseless georg carlin state issu yea...
# 2  brilliant act lesley ann warren best dramat ho...
# 3  easili underr film inn brook cannon sure flaw ...
# 4  typic mel brook film much less slapstick movi ...

# %% [markdown]
# ### Compute TF
# compute term frequency for each document in this part using count_term_frequency function and look what is the shape of new data frames!

# %%
# Insert a new column to the df to store tf for eacg document
def count_term_frequency(document):
    tokens = document.split()
    tf = {}

    for term in tokens:
        if term not in tf:
            tf[term] = 1
        else:
            tf[term] += 1
    
    return tf

# %%
train_pos_df['tf'] = train_pos_df['preprocessed'].apply(count_term_frequency)
train_neg_df['tf'] = train_neg_df['preprocessed'].apply(count_term_frequency)
test_pos_df['tf']  = test_pos_df['preprocessed'].apply(count_term_frequency)
test_neg_df['tf']  = test_neg_df['preprocessed'].apply(count_term_frequency)

# %%
train_pos_df.head()
# Out:
#       ID                                               text  rating  \
# 0      0  Bromwell High is a cartoon comedy. It ran at t...       9
# 1  10000  Homelessness (or Houselessness as George Carli...       8
# 2  10001  Brilliant over-acting by Lesley Ann Warren. Be...      10
# 3  10002  This is easily the most underrated film inn th...       7
# 4  10003  This is not the typical Mel Brooks film. It wa...       8
#
#                                         preprocessed  \
# 0  bromwel high cartoon comedi ran time program s...
# 1  homeless houseless georg carlin state issu yea...
# 2  brilliant act lesley ann warren best dramat ho...
# 3  easili underr film inn brook cannon sure flaw ...
# 4  typic mel brook film much less slapstick movi ...
#
#                                                   tf
# 0  {'bromwel': 4, 'high': 5, 'cartoon': 1, 'comed...
# 1  {'homeless': 4, 'houseless': 1, 'georg': 1, 'c...
# 2  {'brilliant': 1, 'act': 1, 'lesley': 1, 'ann':...
# 3  {'easili': 1, 'underr': 1, 'film': 2, 'inn': 1...
# 4  {'typic': 1, 'mel': 1, 'brook': 2, 'film': 1, ...

# %% [markdown]
# ### Compute CF
# Now, this is the time to compute collection fraquency.

# %%
class_pos_dict = {}
class_neg_dict = {}

# define collection size as T
T = 0
class_pos_size, class_neg_size = 0, 0
trian_distinct_terms = 0

# fill the dictionary of the pos class
for document in train_pos_df['preprocessed']:
    for term in document.split():
        if term not in class_pos_dict:
            class_pos_dict[term] = 1
        else:
            class_pos_dict[term] += 1
    T += len(document.split())

# compute pos class size
class_pos_size = T

# fill the dictionary of the neg class
for document in train_neg_df['preprocessed']:
    for term in document.split():
        if term not in class_neg_dict:
            class_neg_dict[term] = 1
        else:
            class_neg_dict[term] += 1
    T += len(document.split())

# compute neg class size
class_neg_size = T - class_pos_size
trian_distinct_terms = len(class_neg_dict) + len(class_pos_dict)

print(f"Train set size:          {T}")
print(f"Class positive size:     {class_pos_size}\nClass negative size:     {class_neg_size}")
print(f"Distinct collection terms: {trian_distinct_terms}")
print(class_pos_dict)
print(class_neg_dict)
# Out:
# Train set size:          3088439
# Class positive size:     1573809
# Class negative size:     1514630
# Distinct collection terms: 72536
# {'bromwel': 8, 'high': 1105, 'cartoon': 357, 'comedi': 2010, 'ran': 122, 'time': 8499, 'program': 179, 'school': 818, 'life': 4211, 'teacher': 180, 'year': 4055, 'teach': 158, 'profess': 53, 'lead': 1396, 'believ': 1888, 'satir': 212, 'much': 4687, 'closer': 126, 'realiti': 653, 'scrambl': 6, 'surviv': 343, 'financi': 83, 'insight': 186, 'student': 335, 'see': 7493, 'right': 1837, 'pathet': 65, 'pomp': 5, 'petti': 51, 'whole': 1312, 'situat': 662, 'remind': 530, 'knew': 462, 'saw': 1699, 'episod': 1698, 'repeatedli': 52, 'tri': 2510, 'burn': 305, 'immedi': 298, 'recal': 165, 'classic': 1391, 'line': 1503, 'inspector': 84, 'sack': 20, 'one': 14173, 'welcom': 163, 'expect': 1421, 'mani': 3776, 'adult': 538, 'age': 1077, 'think': 4295, 'far': 1359, 'fetch': 63, 'piti': 133, 'homeless': 81, 'houseless': 1, 'georg': 555, 'carlin': 9, 'state': 560, 'issu': 406, 'never': 3226, 'plan': 428, 'help': 1598, 'street': 574, 'consid': 794, 'human': 1364, 'everyth': 1129, 'go': 4249, 'work': 3968, 'vote': 194, 'matter': 718, 'peopl': 4547, 'lost': 810, 'caus': 509, 'worri': 171, 'thing': 3508, 'racism': 86, 'war': 1507, 'iraq': 41, 'pressur': 78, 'kid': 1392, 'succeed': 131, 'technolog': 162, 'elect': 97, 'inflat': 16, 'next': 859, 'end': 4661, 'br': 49235, 'given': 871, 'bet': 137, 'live': 2726, 'month': 233, 'without': 1672, 'luxuri': 31, 'home': 1079, 'entertain': 1606, 'set': 2215, 'bathroom': 57, 'pictur': 1129, 'wall': 267, 'comput': 205, 'treasur': 158, 'like': 10463, 'goddard': 4, 'bolt': 20, 'lesson': 233, 'mel': 71, 'brook': 152, 'direct': 1851, 'star': 2433, 'play': 5099, 'rich': 371, 'man': 3489, 'world': 2533, 'decid': 802, 'make': 6969, 'sissi': 71, 'rival': 160, 'jefferi': 9, 'tambor': 5, 'thirti': 96, 'day': 2310, 'succe': 111, 'want': 2948, 'futur': 606, 'project': 319, 'build': 511, 'thrown': 156, 'bracelet': 9, 'leg': 126, 'monitor': 28, 'everi': 1954, 'move': 1498, 'step': 343, 'sidewalk': 51, 'nicknam': 21, 'pepto': 2, 'vagrant': 3, 'written': 787, 'forehead': 5, 'meet': 1009, 'charact': 7076, 'includ': 1170, 'woman': 1464, 'name': 1352, 'molli': 37, 'lesley': 3, 'ann': 356, 'warren': 63, 'ex': 243, 'dancer': 163, 'got': 1636, 'divorc': 103, 'lose': 486, 'pal': 73, 'sailor': 68, 'howard': 166, 'morri': 69, 'fume': 3, 'teddi': 19, 'wilson': 108, 'alreadi': 619, 'use': 2511, 'survivor': 81, 'reach': 304, 'mutual': 49, 'agreement': 17, 'fight': 1015, 'flight': 93, 'kill': 1459, 'love': 6167, 'connect': 327, 'necessari': 201, 'plot': 2606, 'found': 1321, 'stink': 25, 'observ': 166, 'film': 25313, 'prior': 97, 'show': 5592, 'tender': 109, 'side': 849, 'compar': 561, 'slapstick': 91, 'blaze': 27, 'saddl': 18, 'young': 2345, 'frankenstein': 37, 'spacebal': 5, 'someth': 2155, 'valuabl': 44, 'hand': 1047, 'stupid': 300, 'know': 3613, 'money': 728, 'mayb': 938, 'give': 2992, 'instead': 712, 'monopoli': 6, 'inspir': 528, 'other': 932, 'brilliant': 928, 'act': 3477, 'best': 4324, 'dramat': 454, 'hobo': 4, 'ladi': 624, 'ever': 2736, 'seen': 3416, 'scene': 4995, 'cloth': 237, 'warehous': 12, 'second': 1095, 'none': 341, 'corn': 23, 'face': 1197, 'good': 7843, 'anyth': 1074, 'take': 3442, 'lawyer': 144, 'also': 5551, 'superb': 569, 'accus': 107, 'turncoat': 4, 'sell': 200, 'boss': 290, 'dishonest': 10, 'shrug': 7, 'indiffer': 41, 'say': 3271, 'three': 1203, 'funni': 1953, 'word': 811, 'jeffrey': 59, 'favorit': 1119, 'later': 1325, 'larri': 98, 'sander': 34, 'fantast': 694, 'mad': 357, 'millionair': 48, 'crush': 100, 'ghetto': 36, 'malevol': 21, 'usual': 991, 'hospit': 182, 'invad': 55, 'demolit': 6, 'site': 139, 'look': 4179, 'two': 3735, 'big': 1815, 'digger': 26, 'bleed': 26, 'movi': 22666, 'get': 6475, 'better': 2391, 'quit': 2192, 'often': 970, 'easili': 474, 'underr': 201, 'inn': 11, 'cannon': 54, 'sure': 1438, 'flaw': 395, 'realist': 584, 'view': 1338, 'unlik': 529, 'citizen': 118, 'kane': 70, 'gave': 589, 'loung': 7, 'singer': 190, 'titan': 145, 'italian': 316, 'idiot': 93, 'joke': 519, 'fall': 960, 'flat': 169, 'still': 3364, ' ...
# {'stori': 5694, 'man': 2544, 'unnatur': 46, 'feel': 2402, 'pig': 78, 'start': 2305, 'open': 1036, 'scene': 5602, 'terrif': 82, 'exampl': 835, 'absurd': 275, 'comedi': 1678, 'formal': 8, 'orchestra': 14, 'audienc': 1377, 'turn': 2005, 'insan': 174, 'violent': 252, 'mob': 74, 'crazi': 360, 'chant': 26, 'singer': 163, 'unfortun': 1042, 'stay': 683, 'whole': 1768, 'time': 7699, 'gener': 1056, 'narr': 190, 'eventu': 352, 'make': 8243, 'put': 1601, 'even': 7795, 'era': 215, 'cryptic': 12, 'dialogu': 1010, 'would': 7036, 'shakespear': 113, 'seem': 4055, 'easi': 274, 'third': 384, 'grader': 33, 'technic': 252, 'level': 584, 'better': 3361, 'might': 1658, 'think': 4619, 'good': 7524, 'cinematographi': 406, 'futur': 306, 'great': 2683, 'vilmo': 2, 'zsigmond': 2, 'star': 2024, 'salli': 58, 'kirkland': 23, 'freder': 5, 'forrest': 25, 'seen': 3267, 'briefli': 66, 'airport': 62, 'brand': 76, 'new': 1855, 'luxuri': 33, 'plane': 216, 'load': 176, 'valuabl': 53, 'paint': 297, 'belong': 140, 'rich': 255, 'businessman': 25, 'philip': 42, 'steven': 187, 'jame': 405, 'stewart': 77, 'fli': 376, 'bunch': 593, 'vip': 4, 'estat': 70, 'prepar': 172, 'public': 323, 'museum': 35, 'also': 3608, 'board': 168, 'daughter': 607, 'juli': 78, 'kathleen': 19, 'quinlan': 1, 'son': 587, 'jetlin': 1, 'take': 3215, 'plan': 420, 'mid': 148, 'air': 399, 'hi': 29, 'jack': 334, 'co': 323, 'pilot': 160, 'chamber': 32, 'robert': 452, 'foxworth': 6, 'two': 3173, 'accomplic': 16, 'banker': 11, 'mont': 10, 'markham': 2, 'wilson': 92, 'michael': 536, 'pataki': 8, 'knock': 166, 'passeng': 44, 'crew': 303, 'sleep': 337, 'ga': 112, 'steal': 268, 'cargo': 16, 'land': 297, 'disus': 6, 'strip': 111, 'isol': 65, 'island': 358, 'descent': 43, 'almost': 1574, 'hit': 671, 'oil': 70, 'rig': 20, 'ocean': 50, 'lose': 342, 'control': 321, 'send': 212, 'crash': 203, 'sea': 146, 'sink': 116, 'bottom': 301, 'right': 1717, 'bang': 84, 'middl': 521, 'bermuda': 3, 'triangl': 35, 'short': 917, 'suppli': 62, 'water': 324, 'leak': 21, 'flown': 6, 'mile': 188, 'cours': 1155, 'problem': 1362, 'mount': 36, 'survivor': 105, 'await': 45, 'help': 1231, 'fast': 487, 'run': 1486, 'br': 52636, 'known': 455, 'slightli': 249, 'differ': 1140, 'tile': 2, 'second': 1217, 'sequel': 668, 'smash': 78, 'disast': 247, 'thriller': 419, 'direct': 1957, 'jerri': 153, 'jameson': 20, 'like': 12343, 'predecessor': 51, 'say': 4187, 'sort': 934, 'forgotten': 166, 'classic': 769, 'entertain': 1224, 'although': 1037, 'necessarili': 82, 'reason': 2014, 'three': 1095, 'film': 22894, 'far': 1620, 'actual': 2903, 'one': 13576, 'best': 2100, 'favourit': 82, 'plot': 4365, 'nice': 967, 'see': 6622, 'mayb': 1404, 'maker': 416, 'tri': 3847, 'cross': 227, 'origin': 2327, 'anoth': 2255, 'popular': 257, 'flick': 1045, 'period': 356, 'poseidon': 3, 'adventur': 244, 'submerg': 7, 'end': 4994, 'stark': 15, 'dilemma': 28, 'face': 1095, 'trap': 199, 'insid': 274, 'either': 1183, 'suffoc': 8, 'drown': 82, 'flood': 28, 'door': 310, 'decent': 830, 'idea': 1654, 'could': 4685, 'made': 4541, 'littl': 3096, 'bad': 7437, 'unsympathet': 42, 'charact': 7108, 'dull': 692, 'letharg': 20, 'set': 1902, 'piec': 1093, 'real': 2171, 'lack': 1225, 'danger': 250, 'suspens': 483, 'tension': 282, 'mean': 1738, 'miss': 1003, 'opportun': 244, 'rather': 1394, 'sluggish': 16, 'keep': 1114, 'odd': 328, 'minut': 2612, 'much': 5077, 'happen': 2034, 'urgenc': 16, 'thought': 1913, 'navi': 43, 'becom': 1419, 'involv': 1027, 'thing': 4705, 'pick': 552, 'shot': 1685, 'huge': 543, 'ship': 245, 'helicopt': 80, 'someth': 2968, 'georg': 380, 'kennedi': 32, 'jinx': 7, 'airlin': 25, 'worker': 114, 'joe': 301, 'patroni': 2, 'back': 2503, 'get': 7667, 'coupl': 987, 'bare': 422, 'anyth': 1874, 'prefer': 176, 'look': 5875, 'worri': 159, 'background': 318, 'home': 879, 'video': 1119, 'theatric': 104, 'version': 1077, 'us': 1629, 'tv': 1387, 'add': 545, 'extra': 257, 'hour': 1359, 'footag': 383, 'includ': 851, 'credit': 727, 'sequenc': 733, 'mani': 2912, 'flashback': 222, 'flesh': 188,  ...

# %% [markdown]
# The output above shows that for instance, the word 'high' is used in the class positive 1105 times.

# %% [markdown]
# ## Naive Bayes
# In this part i want to use Bayes classifier to do the classification task on test data.

# %% [markdown]
# #### Classification rule:
#
# \begin{equation*}
# c_{map} = argmax_{c\in C} \left[log\hat{P}(c) + \sum_{1 \le k \le n_d} log\hat{P}(t_k|c) \right]
# \end{equation*}

# %% [markdown]
# As there are 2 classes and both of them have size 12500, it is not requered to compute $\hat{P}(c)=\frac{N_c}{N}$. So, we have the below rule:
# \begin{equation*}
# c_{map} = argmax_{c\in C} \left[\sum_{1 \le k \le n_d} log\hat{P}(t_k|c) \right]
# \end{equation*}

# %% [markdown]
# \begin{equation*}
# \hat{P}(t_k|c) = \frac{T_{ct}+1}{\sum_{t'\in V} (T_{ct'}+1)} = \frac{T_{ct}+1}{(\sum_{t'\in V} T_{ct'})+B}
# \end{equation*}

# %% [markdown]
# ### Class POSITIVE
#
# We have to compute the last condotional probability for all of the terms in class positive.

# %%
P_pos = {}

for term in class_pos_dict:
    P_pos[term] = (class_pos_dict[term] + 1)/(class_pos_size + trian_distinct_terms)

# %% [markdown]
# ### Class NEGATIVE

# %%
P_neg = {}

for term in class_neg_dict:
    P_neg[term] = (class_neg_dict[term] + 1)/(class_neg_size + trian_distinct_terms)

# %% [markdown]
# ## Evalute test set : using multiplication

# %% [markdown]
# #### Fisrt part: Evaluating positive labels of test set

# %%
classification_result = []

for document in test_pos_df['preprocessed']:
    # As we used multiplication in this section, we set the initial 
    # amounts as 1
    P_c1 = 1
    P_c2 = 1
    '''
    for reach term  in the documnet, if it is in class positive(negative), 
    we compute P_pos(P_neg) for that term and add it to the dict P_pos(P_neg)
    '''
    for term in document.split():
        if term not in P_pos:
            P_pos[term] = 1 / (class_pos_size + trian_distinct_terms)
        P_c1 *= P_pos[term] # multiplication

        if term not in P_neg:
            P_neg[term] = 1 / (class_neg_size + trian_distinct_terms)
        P_c2 *= P_neg[term]

    '''
    if the probability of belonging to the class positive is more than class negative,
    then append 1(for class positive) to the results array. else, append 
    2(for class negative)
    '''
    if P_c1 >= P_c2:
        classification_result.append(1)
    else: 
        classification_result.append(2)
    

print("Result of classification on positive test documents: ")
print(f"Number of documents in test set whcih are predicted to be in class pos: {classification_result.count(1)}")
print(f"Number of documents in test set whcih are predicted to be in class neg: {classification_result.count(2)}")
pos_acc = classification_result.count(1)/len(test_pos_df)
print(f"Accuracy: {pos_acc}")
# Out:
# Result of classification on positive test documents:
# Number of documents in test set whcih are predicted to be in class pos: 10732
# Number of documents in test set whcih are predicted to be in class neg: 1768
# Accuracy: 0.85856

# %% [markdown]
# #### Fisrt part: Evaluating negative labels of test set

# %%
for document in test_neg_df['preprocessed']:
    P_c1 = 1
    P_c2 = 1
    '''
    for reach term  in the documnet, if it is in class positive(negative), 
    we compute P_pos(P_neg) for that term and add it to the dict P_pos(P_neg)
    '''
    for term in document.split():
        if term not in P_pos:
            P_pos[term] = 1 / (class_pos_size + trian_distinct_terms)
        P_c1 *= P_pos[term]

        if term not in P_neg:
            P_neg[term] = 1 / (class_neg_size + trian_distinct_terms)
        P_c2 *= P_neg[term]
    '''
    if the probability of belonging to the class positive is more than class negative,
    then append 1(for class positive) to the results array. else, append 
    2(for class negative)
    '''
    if P_c1 >= P_c2:
        classification_result.append(1)
    else: 
        classification_result.append(2)
    


print("Result of classification on negative test documents: ")
print(f"Number of documents in test set whcih are predicted to be in class pos: {classification_result[12500:].count(1)}")
print(f"Number of documents in test set whcih are predicted to be in class neg: {classification_result[12500:].count(2)}")
neg_acc = classification_result[12500:].count(2)/len(test_pos_df)
print(f"Accuracy: {neg_acc}")
# Out:
# Result of classification on negative test documents:
# Number of documents in test set whcih are predicted to be in class pos: 6396
# Number of documents in test set whcih are predicted to be in class neg: 6104
# Accuracy: 0.48832

# %% [markdown]
# ## Using log

# %%
'''
We use the above code here too. the only difference in that we use log to 
convert multiplication to sum and improve tha results.
'''
classification_result = []

for document in test_pos_df['preprocessed']:
    # As we use log in this section, the initial amounts should be set on 0
    P_c1 = 0
    P_c2 = 0
    for term in document.split():
        if term not in P_pos:
            P_pos[term] = 1 / (class_pos_size + trian_distinct_terms)
        P_c1 += math.log2(P_pos[term]) # Log is here

        if term not in P_neg:
            P_neg[term] = 1 / (class_neg_size + trian_distinct_terms)
        P_c2 += math.log2(P_neg[term])

    if P_c1 >= P_c2:
        classification_result.append(1)
    else: 
        classification_result.append(2)
    

TP1 = classification_result.count(1)
print("Result of classification on positive test documents: ")
print(f"Number of documents in test set whcih are predicted to be in class pos: {classification_result.count(1)}")
print(f"Number of documents in test set whcih are predicted to be in class neg: {classification_result.count(2)}")
pos_acc = classification_result.count(1)/len(test_pos_df)
print(f"Accuracy: {pos_acc}")
# Out:
# Result of classification on positive test documents:
# Number of documents in test set whcih are predicted to be in class pos: 9525
# Number of documents in test set whcih are predicted to be in class neg: 2975
# Accuracy: 0.762

# %%
for document in test_neg_df['preprocessed']:
    P_c1 = 1
    P_c2 = 1
    for term in document.split():
        if term not in P_pos:
            P_pos[term] = 1 / (class_pos_size + trian_distinct_terms)
        P_c1 += math.log2(P_pos[term])

        if term not in P_neg:
            P_neg[term] = 1 / (class_neg_size + trian_distinct_terms)
        P_c2 += math.log2(P_neg[term])

    if P_c1 >= P_c2:
        classification_result.append(1)
    else: 
        classification_result.append(2)
    

TP2 = classification_result[12500:].count(2)
print("Result of classification on negative test documents: ")
print(f"Number of documents in test set whcih are predicted to be in class pos: {classification_result[12500:].count(1)}")
print(f"Number of documents in test set whcih are predicted to be in class neg: {classification_result[12500:].count(2)}")
neg_acc = classification_result[12500:].count(2)/len(test_pos_df)
print(f"Accuracy: {neg_acc}")
# Out:
# Result of classification on negative test documents:
# Number of documents in test set whcih are predicted to be in class pos: 1574
# Number of documents in test set whcih are predicted to be in class neg: 10926
# Accuracy: 0.87408

# %% [markdown]
# Now, compute the accuracy of the classification:

# %%
print(f"Naive Bayes classifier accuracy: {(TP1+TP2)/(len(test_neg_df) + len(test_pos_df))}")
# Out:
# Naive Bayes classifier accuracy: 0.81804

# %% [markdown]
# # Word embedding and LSA with SVM classifier

# %%
# Consider the whole train data as a single data frame
df = pd.concat([train_pos_df, train_neg_df], ignore_index=True)
df.index += 1
df
# Out:
#           ID                                               text  rating  \
# 1          0  Bromwell High is a cartoon comedy. It ran at t...       9
# 2      10000  Homelessness (or Houselessness as George Carli...       8
# 3      10001  Brilliant over-acting by Lesley Ann Warren. Be...      10
# 4      10002  This is easily the most underrated film inn th...       7
# 5      10003  This is not the typical Mel Brooks film. It wa...       8
# ...      ...                                                ...     ...
# 24996   9998  Towards the end of the movie, I felt it was to...       4
# 24997   9999  This is the kind of movie that my enemies cont...       3
# 24998    999  I saw 'Descent' last night at the Stockholm Fi...       3
# 24999     99  Some films that you pick up for a pound turn o...       1
# 25000      9  This is one of the dumbest films, I've ever se...       1
#
#                                             preprocessed  \
# 1      bromwel high cartoon comedi ran time program s...
# 2      homeless houseless georg carlin state issu yea...
# 3      brilliant act lesley ann warren best dramat ho...
# 4      easili underr film inn brook cannon sure flaw ...
# 5      typic mel brook film much less slapstick movi ...
# ...                                                  ...
# 24996  toward end movi felt technic felt like classro...
# 24997  kind movi enemi content watch time bloodi true...
# 24998  saw descent last night stockholm film festiv o...
# 24999  film pick pound turn rather good rd centuri fi...
# 25000  one dumbest film ever seen rip nearli ever typ...
#
#                                                       tf
# 1      {'bromwel': 4, 'high': 5, 'cartoon': 1, 'comed...
# 2      {'homeless': 4, 'houseless': 1, 'georg': 1, 'c...
# 3      {'brilliant': 1, 'act': 1, 'lesley': 1, 'ann':...
# 4      {'easili': 1, 'underr': 1, 'film': 2, 'inn': 1...
# 5      {'typic': 1, 'mel': 1, 'brook': 2, 'film': 1, ...
# ...                                                  ...
# 24996  {'toward': 1, 'end': 1, 'movi': 7, 'felt': 2, ...
# 24997  {'kind': 3, 'movi': 3, 'enemi': 1, 'content': ...
# 24998  {'saw': 1, 'descent': 1, 'last': 1, 'night': 1...
# 24999  {'film': 7, 'pick': 1, 'pound': 1, 'turn': 1, ...
# 25000  {'one': 1, 'dumbest': 1, 'film': 2, 'ever': 2,...
#
# [25000 rows x 5 columns]

# %%
# Consider the whole test data as a single data frame
test_set = pd.concat([test_pos_df, test_neg_df], ignore_index=True)
test_set.index += 1
test_set
# Out:
#           ID                                               text  rating  \
# 1          0  I went and saw this movie last night after bei...      10
# 2      10000  Actor turned director Bill Paxton follows up h...       7
# 3      10001  As a recreational golfer with some knowledge o...       9
# 4      10002  I saw this film in a sneak preview, and it is ...       8
# 5      10003  Bill Paxton has taken the true story of the 19...       8
# ...      ...                                                ...     ...
# 24996   9998  I occasionally let my kids watch this garbage ...       1
# 24997   9999  When all we have anymore is pretty much realit...       1
# 24998    999  The basic genre is a thriller intercut with an...       3
# 24999     99  Four things intrigued me as to this film - fir...       3
# 25000      9  David Bryce's comments nearby are exceptionall...       4
#
#                                             preprocessed  \
# 1      went saw movi last night coax friend mine admi...
# 2      actor turn director bill paxton follow promis ...
# 3      recreat golfer knowledg sport histori pleas di...
# 4      saw film sneak preview delight cinematographi ...
# 5      bill paxton taken true stori us golf open made...
# ...                                                  ...
# 24996  occasion let kid watch garbag understand pathe...
# 24997  anymor pretti much realiti tv show peopl make ...
# 24998  basic genr thriller intercut uncomfort menag t...
# 24999  four thing intrigu film firstli star carli pop...
# 25000  david bryce comment nearbi except well written...
#
#                                                       tf
# 1      {'went': 1, 'saw': 2, 'movi': 4, 'last': 1, 'n...
# 2      {'actor': 1, 'turn': 1, 'director': 1, 'bill':...
# 3      {'recreat': 1, 'golfer': 1, 'knowledg': 1, 'sp...
# 4      {'saw': 1, 'film': 3, 'sneak': 1, 'preview': 1...
# 5      {'bill': 1, 'paxton': 1, 'taken': 1, 'true': 1...
# ...                                                  ...
# 24996  {'occasion': 1, 'let': 1, 'kid': 1, 'watch': 1...
# 24997  {'anymor': 1, 'pretti': 1, 'much': 1, 'realiti...
# 24998  {'basic': 1, 'genr': 1, 'thriller': 2, 'interc...
# 24999  {'four': 1, 'thing': 1, 'intrigu': 1, 'film': ...
# 25000  {'david': 1, 'bryce': 1, 'comment': 1, 'nearbi...
#
# [25000 rows x 5 columns]

# %% [markdown]
# Construct the labels for train and test datasets

# %%
y_train = np.concatenate([np.ones(12500), np.zeros(12500)])
y_test = np.copy(y_train)

# %% [markdown]
# #### Preprocess train and test set + compute TF:

# %%
# Apply preprocessing on train and test dataframes and compute term frequency
df['preprocessed'] = df['text'].apply(preprocessing)
df['tf'] = df['preprocessed'].apply(count_term_frequency)

test_set['preprocessed'] = test_set['text'].apply(preprocessing)
test_set['tf'] = test_set['preprocessed'].apply(count_term_frequency)

# %% [markdown]
# Make new pandas series for test and train datasets

# %%
train_text = df.text.apply(preprocessing)
train_text = train_text.apply(gensim.utils.simple_preprocess)

# %%
test_text = test_set.text.apply(preprocessing)
test_text = test_text.apply(gensim.utils.simple_preprocess)

# %% [markdown]
# This is the form of pandas series:

# %%
print(train_text.loc[1])
# Out:
# ['bromwel', 'high', 'cartoon', 'comedi', 'ran', 'time', 'program', 'school', 'life', 'teacher', 'year', 'teach', 'profess', 'lead', 'believ', 'bromwel', 'high', 'satir', 'much', 'closer', 'realiti', 'teacher', 'scrambl', 'surviv', 'financi', 'insight', 'student', 'see', 'right', 'pathet', 'teacher', 'pomp', 'petti', 'whole', 'situat', 'remind', 'school', 'knew', 'student', 'saw', 'episod', 'student', 'repeatedli', 'tri', 'burn', 'school', 'immedi', 'recal', 'high', 'classic', 'line', 'inspector', 'sack', 'one', 'teacher', 'student', 'welcom', 'bromwel', 'high', 'expect', 'mani', 'adult', 'age', 'think', 'bromwel', 'high', 'far', 'fetch', 'piti']

# %%
print(df.text.loc[1])
# Out:
# Bromwell High is a cartoon comedy. It ran at the same time as some other programs about school life, such as "Teachers". My 35 years in the teaching profession lead me to believe that Bromwell High's satire is much closer to reality than is "Teachers". The scramble to survive financially, the insightful students who can see right through their pathetic teachers' pomp, the pettiness of the whole situation, all remind me of the schools I knew and their students. When I saw the episode in which a student repeatedly tried to burn down the school, I immediately recalled ......... at .......... High. A classic line: INSPECTOR: I'm here to sack one of your teachers. STUDENT: Welcome to Bromwell High. I expect that many adults of my age think that Bromwell High is far fetched. What a pity that it isn't!

# %%
df.head()
# Out:
#       ID                                               text  rating  \
# 1      0  Bromwell High is a cartoon comedy. It ran at t...       9
# 2  10000  Homelessness (or Houselessness as George Carli...       8
# 3  10001  Brilliant over-acting by Lesley Ann Warren. Be...      10
# 4  10002  This is easily the most underrated film inn th...       7
# 5  10003  This is not the typical Mel Brooks film. It wa...       8
#
#                                         preprocessed  \
# 1  bromwel high cartoon comedi ran time program s...
# 2  homeless houseless georg carlin state issu yea...
# 3  brilliant act lesley ann warren best dramat ho...
# 4  easili underr film inn brook cannon sure flaw ...
# 5  typic mel brook film much less slapstick movi ...
#
#                                                   tf
# 1  {'bromwel': 4, 'high': 5, 'cartoon': 1, 'comed...
# 2  {'homeless': 4, 'houseless': 1, 'georg': 1, 'c...
# 3  {'brilliant': 1, 'act': 1, 'lesley': 1, 'ann':...
# 4  {'easili': 1, 'underr': 1, 'film': 2, 'inn': 1...
# 5  {'typic': 1, 'mel': 1, 'brook': 2, 'film': 1, ...

# %%
test_set.head()
# Out:
#       ID                                               text  rating  \
# 1      0  I went and saw this movie last night after bei...      10
# 2  10000  Actor turned director Bill Paxton follows up h...       7
# 3  10001  As a recreational golfer with some knowledge o...       9
# 4  10002  I saw this film in a sneak preview, and it is ...       8
# 5  10003  Bill Paxton has taken the true story of the 19...       8
#
#                                         preprocessed  \
# 1  went saw movi last night coax friend mine admi...
# 2  actor turn director bill paxton follow promis ...
# 3  recreat golfer knowledg sport histori pleas di...
# 4  saw film sneak preview delight cinematographi ...
# 5  bill paxton taken true stori us golf open made...
#
#                                                   tf
# 1  {'went': 1, 'saw': 2, 'movi': 4, 'last': 1, 'n...
# 2  {'actor': 1, 'turn': 1, 'director': 1, 'bill':...
# 3  {'recreat': 1, 'golfer': 1, 'knowledg': 1, 'sp...
# 4  {'saw': 1, 'film': 3, 'sneak': 1, 'preview': 1...
# 5  {'bill': 1, 'paxton': 1, 'taken': 1, 'true': 1...

# %% [markdown]
# # W2V
# in this section, we used word2vec as the word embedding and we will do the classification using this.

# %%
# consider each vector size for each word in train set as 100.
# window: 5, which means that the model will consider 5 words befor and afterm the target word
# min_count: 1, even consider words which are used only once
train_model = Word2Vec(sentences=train_text, vector_size=100, window=5, min_count=1, workers=4)

# %%
train_model.wv.index_to_key
# Out:
# ['br',
#  'movi',
#  'film',
#  'one',
#  'like',
#  'time',
#  'good',
#  'make',
#  'charact',
#  'get',
#  'see',
#  'watch',
#  'stori',
#  'even',
#  'would',
#  'realli',
#  'well',
#  'scene',
#  'look',
#  'show',
#  'much',
#  'end',
#  'peopl',
#  'bad',
#  'go',
#  'great',
#  'also',
#  'first',
#  'love',
#  'think',
#  'way',
#  'act',
#  'play',
#  'made',
#  'thing',
#  'could',
#  'know',
#  'say',
#  'seem',
#  'work',
#  'plot',
#  'two',
#  'year',
#  'actor',
#  'come',
#  'mani',
#  'seen',
#  'take',
#  'life',
#  'want',
#  'never',
#  'littl',
#  'best',
#  'tri',
#  'man',
#  'ever',
#  'give',
#  'better',
#  'still',
#  'perform',
#  'find',
#  'feel',
#  'part',
#  'back',
#  'director',
#  'use',
#  'someth',
#  'actual',
#  'interest',
#  'lot',
#  'real',
#  'old',
#  'cast',
#  'though',
#  'live',
#  'star',
#  'enjoy',
#  'guy',
#  'anoth',
#  'new',
#  'role',
#  'noth',
#  'funni',
#  'music',
#  'point',
#  'start',
#  'set',
#  'girl',
#  'origin',
#  'day',
#  'world',
#  'everi',
#  'believ',
#  'turn',
#  'quit',
#  'direct',
#  'us',
#  'thought',
#  'fact',
#  'minut',
#  'horror',
#  'kill',
#  'action',
#  'comedi',
#  'pretti',
#  'young',
#  'wonder',
#  'happen',
#  'around',
#  'got',
#  'effect',
#  'right',
#  'long',
#  'howev',
#  'big',
#  'line',
#  'famili',
#  'enough',
#  'seri',
#  'may',
#  'need',
#  'fan',
#  'bit',
#  'script',
#  'beauti',
#  'person',
#  'becom',
#  'without',
#  'must',
#  'alway',
#  'friend',
#  'tell',
#  'reason',
#  'saw',
#  'last',
#  'kid',
#  'final',
#  'almost',
#  'put',
#  'least',
#  'sure',
#  'done',
#  'whole',
#  'place',
#  'complet',
#  'expect',
#  'kind',
#  'differ',
#  'shot',
#  'far',
#  'mean',
#  'anyth',
#  'book',
#  'laugh',
#  'might',
#  'name',
#  'sinc',
#  'begin',
#  'probabl',
#  'woman',
#  'entertain',
#  'help',
#  'let',
#  'screen',
#  'call',
#  'moment',
#  'tv',
#  'away',
#  'read',
#  'yet',
#  'rather',
#  'worst',
#  'run',
#  'fun',
#  'lead',
#  'hard',
#  'audienc',
#  'idea',
#  'anyon',
#  'episod',
#  'american',
#  'found',
#  'appear',
#  'bore',
#  'especi',
#  'although',
#  'hope',
#  'keep',
#  'cours',
#  'anim',
#  'job',
#  'goe',
#  'move',
#  'sens',
#  'dvd',
#  'version',
#  'war',
#  'money',
#  'someon',
#  'mind',
#  'mayb',
#  'problem',
#  'true',
#  'hous',
#  'everyth',
#  'second',
#  'nice',
#  'rate',
#  'three',
#  'follow',
#  'night',
#  'face',
#  'recommend',
#  'product',
#  'main',
#  'worth',
#  'leav',
#  'human',
#  'special',
#  'excel',
#  'togeth',
#  'sound',
#  'wast',
#  'everyon',
#  'john',
#  'hand',
#  'father',
#  'eye',
#  'later',
#  'said',
#  'view',
#  'instead',
#  'review',
#  'boy',
#  'high',
#  'hour',
#  'talk',
#  'classic',
#  'miss',
#  'wife',
#  'understand',
#  'black',
#  'left',
#  'care',
#  'death',
#  'open',
#  'murder',
#  'write',
#  'half',
#  'head',
#  'rememb',
#  'chang',
#  'viewer',
#  'fight',
#  'surpris',
#  'short',
#  'gener',
#  'includ',
#  'die',
#  'els',
#  'fall',
#  'less',
#  'entir',
#  'piec',
#  'involv',
#  'pictur',
#  'simpli',
#  'top',
#  'home',
#  'power',
#  'total',
#  'usual',
#  'budget',
#  'attempt',
#  'suppos',
#  'releas',
#  'hollywood',
#  'song',
#  'terribl',
#  'men',
#  'possibl',
#  'featur',
#  'portray',
#  'disappoint',
#  'poor',
#  'coupl',
#  'camera',
#  'stupid',
#  'dead',
#  'wrong',
#  'produc',
#  'low',
#  'video',
#  'either',
#  'aw',
#  'definit',
#  'except',
#  'rest',
#  'given',
#  'absolut',
#  'women',
#  'lack',
#  'word',
#  'writer',
#  'titl',
#  'talent',
#  'decid',
#  'full',
#  'perfect',
#  'along',
#  'style',
#  'close',
#  'truli',
#  'school',
#  'emot',
#  'save',
#  'sex',
#  'age',
#  'next',
#  'bring',
#  'mr',
#  'case',
#  'killer',
#  'heart',
#  'comment',
#  'perhap',
#  'sort',
#  'creat',
#  'came',
#  'brother',
#  'sever',
#  'joke',
#  'game',
#  'dialogu',
#  'art',
#  'small',
#  'base',
#  'flick',
#  'written',
#  'sequenc',
#  'meet',
#  'earli',
#  'often',
#  'other',
#  'mother',
#  'develop',
#  'humor',
#  'actress',
#  'consid',
#  'dark',
#  'guess',
#  'unfortun',
#  'amaz',
#  'cinema',
#  'exampl',
#  'light',
#  'lost',
#  'drama',
#  'ye',
#  'white',
#  'experi',
#  'imagin',
#  'mention',
#  'stop',
#  'natur',
#  'forc',
#  'manag',
#  'felt',
#  'present',
#  'cut',
#  'children',
#  'fail',
#  'qualiti',
#  'son',
#  'car',
#  'support',
#  'ask',
#  'hit',
#  'side',
#  'voic',
#  'extrem',
#  'impress',
#  'wors',
#  'evil',
#  'went',
#  'stand',
#  'certainli',
#  'basic',
#  'oh',
#  'overal',
#  'favorit',
#  'horribl',
#  'mysteri',
#  'number',
#  'type',
#  'danc',
#  'wait',
#  'hero',
#  'alreadi',
#  'learn',
#  'matter',
#  'michael',
#  'genr',
#  'fine',
#  'despit',
#  'throughout',
#  'walk',
#  'success',
#  'histori',
#  'question',
#  'zombi',
#  'town',
#  'child',
#  'realiz',
#  'relationship',
#  'past',
#  'daughter',
#  'late',
#  'wish',
#  'hate',
#  'credit',
#  'event',
#  'theme',
#  'touch',
#  'citi',
#  'today',
#  'sometim',
#  'behind',
#  'god',
#  'twist',
#  'sit',
#  'annoy',
#  'deal',
#  'stay',
#  'abl',
#  'rent',
#  'pleas',
#  'edit',
#  'blood',
#  'deserv',
#  'anyway',
#  'comic',
#  'appar',
#  'soon',
#  'gave',
#  'etc',
#  'level',
#  'slow',
#  'chanc',
#  'score',
#  'bodi',
#  'brilliant',
#  'incred',
#  'figur',
#  'situat',
#  'major',
#  'self',
#  'stuff',
#  'decent',
#  'element',
#  'return',
#  'dream',
#  'obvious',
#  'continu',
#  'order',
#  'pace',
#  'ridicul',
#  'happi',
#  'highli',
#  'thank',
#  'add',
#  'group',
#  'ladi',
#  'novel',
#  'speak',
#  'pain',
#  'career',
#  'strang',
#  'shoot',
#  'heard',
#  'sad',
#  'husband',
#  'polic',
#  'break',
#  'import',
#  'took',
#  'strong',
#  'cannot',
#  'predict',
#  'robert',
#  'violenc',
#  'hilari',
#  'recent',
#  'countri',
#  'known',
#  'particularli',
#  'pick',
#  'documentari',
#  'season',
#  'critic',
#  'jame',
#  'compar',
#  'obviou',
#  'alon',
#  'told',
#  'state',
#  'visual',
#  'rock',
#  'exist',
#  'theater',
#  'gore',
#  'offer',
#  'opinion',
#  'crap',
#  'hold',
#  'result',
#  'hear',
#  'room',
#  'realiti',
#  'thriller',
#  'effort',
#  'caus',
#  'explain',
#  'sequel',
#  'serious',
#  'king',
#  'local',
#  'ago',
#  'none',
#  'hell',
#  'note',
#  'allow',
#  'david',
#  'sister',
#  'femal',
#  'simpl',
#  'deliv',
#  'check',
#  'ok',
#  'convinc',
#  'class',
#  'suspens',
#  'buy',
#  'oscar',
#  'win',
#  'huge',
#  'sexual',
#  'valu',
#  'scari',
#  'cool',
#  'excit',
#  'spoiler',
#  'similar',
#  'avoid',
#  'exactli',
#  'provid',
#  'apart',
#  'shown',
#  'seriou',
#  'taken',
#  'english',
#  'whose',
#  'cinematographi',
#  'polit',
#  'shock',
#  'offic',
#  'across',
#  'middl',
#  'street',
#  'silli',
#  'messag',
#  'somewhat',
#  'charm',
#  'modern',
#  'pass',
#  'filmmak',
#  'confus',
#  'form',
#  'tale',
#  'singl',
#  'jack',
#  'mostli',
#  'sing',
#  'william',
#  'attent',
#  'subject',
#  'richard',
#  'prove',
#  'five',
#  'carri',
#  'team',
#  'georg',
#  'stage',
#  'unlik',
#  'cop',
#  'monster',
#  'televis',
#  'earth',
#  'villain',
#  'cover',
#  'pay',
#  'marri',
#  'toward',
#  'build',
#  'parent',
#  'pull',
#  'respect',
#  'due',
#  'fill',
#  'four',
#  'dialog',
#  'remind',
#  'futur',
#  'weak',
#  'typic',
#  'intellig',
#  'cheap',
#  'atmospher',
#  'british',
#  'clearli',
#  'non',
#  'knew',
#  'dog',
#  'fast',
#  'artist',
#  'paul',
#  'crime',
#  'easili',
#  'escap',
#  'adult',
#  'doubt',
#  'detail',
#  'date',
#  'romant',
#  'member',
#  'fire',
#  'drive',
#  'gun',
#  'straight',
#  'beyond',
#  'fit',
#  'attack',
#  'imag',
#  'upon',
#  'posit',
#  'whether',
#  'fantast',
#  'peter',
#  'aspect',
#  'appreci',
#  'captur',
#  'ten',
#  'discov',
#  'plan',
#  'remain',
#  'period',
#  'realist',
#  'near',
#  'air',
#  'mark',
#  'adapt',
#  'dull',
#  'red',
#  'within',
#  'spend',
#  'lose',
#  'materi',
#  'color',
#  'chase',
#  'forget',
#  'mari',
#  'storylin',
#  'bunch',
#  'clear',
#  'match',
#  'lee',
#  'victim',
#  'nearli',
#  'box',
#  'york',
#  'inspir',
#  'finish',
#  'standard',
#  'mess',
#  'easi',
#  'truth',
#  'busi',
#  'suffer',
#  'bill',
#  'dramat',
#  'space',
#  'western',
#  'list',
#  'battl',
#  'notic',
#  'ad',
#  'de',
#  'french',
#  'tom',
#  'larg',
#  'among',
#  'eventu',
#  'train',
#  'accept',
#  'agre',
#  'spirit',
#  'soundtrack',
#  'third',
#  'teenag',
#  'adventur',
#  'soldier',
#  'famou',
#  'sorri',
#  'drug',
#  'suggest',
#  'cri',
#  'babi',
#  'normal',
#  'troubl',
#  'ultim',
#  'contain',
#  'certain',
#  'cultur',
#  'romanc',
#  'lame',
#  'rare',
#  'somehow',
#  'mix',
#  'disney',
#  'gone',
#  'student',
#  'fear',
#  'cartoon',
#  'reveal',
#  'suck',
#  'attract',
#  'kept',
#  'appeal',
#  'premis',
#  'secret',
#  'greatest',
#  'design',
#  'shame',
#  'copi',
#  'throw',
#  'th',
#  'scare',
#  'wit',
#  'admit',
#  'america',
#  'relat',
#  'brought',
#  'particular',
#  'screenplay',
#  'whatev',
#  'pure',
#  'averag',
#  'master',
#  'harri',
#  'describ',
#  'male',
#  'treat',
#  'issu',
#  'fantasi',
#  'warn',
#  'inde',
#  'background',
#  'forward',
#  'free',
#  'project',
#  'japanes',
#  'okay',
#  'memor',
#  'poorli',
#  'award',
#  'locat',
#  'amus',
#  'potenti',
#  'struggl',
#  'societi',
#  'magic',
#  'weird',
#  'imdb',
#  'accent',
#  'doctor',
#  'express',
#  'hot',
#  'water',
#  'odd',
#  'alien',
#  'choic',
#  'dr',
#  'crazi',
#  'studio',
#  'masterpiec',
#  'control',
#  'fiction',
#  'becam',
#  'difficult',
#  'fli',
#  'joe',
#  'scream',
#  'costum',
#  'refer',
#  'lover',
#  'uniqu',
#  'remak',
#  'vampir',
#  'girlfriend',
#  'prison',
#  'execut',
#  'wear',
#  'jump',
#  'wood',
#  'unless',
#  'cheesi',
#  'creepi',
#  'superb',
#  'otherwis',
#  'parti',
#  'roll',
#  'ghost',
#  'public',
#  'mad',
#  'badli',
#  'depict',
#  'earlier',
#  'jane',
#  'moral',
#  'week',
#  'flaw',
#  'dumb',
#  'fi',
#  'grow',
#  'deep',
#  'sci',
#  'maker',
#  'cat',
#  'older',
#  'footag',
#  'bother',
#  'cliché',
#  'connect',
#  'plenti',
#  'outsid',
#  'stick',
#  'gay',
#  'catch',
#  'plu',
#  'popular',
#  'co',
#  'equal',
#  'disturb',
#  'social',
#  'quickli',
#  'perfectli',
#  'dress',
#  'era',
#  'mistak',
#  'ride',
#  'previou',
#  'combin',
#  'lie',
#  'band',
#  'concept',
#  'answer',
#  'surviv',
#  'rich',
#  'front',
#  'sweet',
#  'christma',
#  'insid',
#  'concern',
#  'bare',
#  'eat',
#  'ben',
#  'listen',
#  'beat',
#  'term',
#  'serv',
#  'meant',
#  'stereotyp',
#  'german',
#  'hardli',
#  'la',
#  'law',
#  'desper',
#  'innoc',
#  'memori',
#  'promis',
#  'cute',
#  'variou',
#  'steal',
#  'intent',
#  'inform',
#  'brain',
#  'post',
#  'tone',
#  'island',
#  'nuditi',
#  'amount',
#  'track',
#  'compani',
#  'store',
#  'claim',
#  'flat',
#  'hair',
#  'land',
#  'univers',
#  'kick',
#  'danger',
#  'fairli',
#  'scott',
#  'player',
#  'step',
#  'plain',
#  'crew',
#  'toni',
#  'share',
#  'tast',
#  'centuri',
#  'achiev',
#  'travel',
#  'record',
#  'cold',
#  'engag',
#  'rip',
#  'suit',
#  'wrote',
#  'manner',
#  'tension',
#  'sadli',
#  'spot',
#  'intens',
#  'fascin',
#  'familiar',
#  'histor',
#  'depth',
#  'burn',
#  'remark',
#  'destroy',
#  'languag',
#  'sleep',
#  'purpos',
#  'ruin',
#  'ignor',
#  'unbeliev',
#  'delight',
#  'italian',
#  'soul',
#  'collect',
#  'abil',
#  'detect',
#  'clever',
#  'violent',
#  'rape',
#  'reach',
#  'door',
#  'scienc',
#  'trash',
#  'liter',
#  'commun',
#  'caught',
#  'reveng',
#  'creatur',
#  'trip',
#  'approach',
#  'fashion',
#  'intrigu',
#  'introduc',
#  'paint',
#  'skill',
#  'complex',
#  'channel',
#  'camp',
#  'million',
#  'christian',
#  'extra',
#  'hole',
#  'comput',
#  'limit',
#  'immedi',
#  'mental',
#  'ann',
#  'slightli',
#  'mere',
#  'teen',
#  'conclus',
#  'slasher',
#  'crimin',
#  'suddenli',
#  'imposs',
#  'nation',
#  'neither',
#  'spent',
#  'physic',
#  'respons',
#  'fake',
#  'planet',
#  'receiv',
#  ...]

# %% [markdown]
# Now, we have to make our train data such that construct a vector for each documnet as the mean of all its words vectoes.

# %%
X_train = []
for i in range(len(train_text)):
    doc_model = np.zeros(100)
    for word in train_text[i+1]:
        doc_model += train_model.wv[word]
    X_train.append(doc_model/len(train_text[i+1]))

print(len(X_train))
# Out:
# 25000

# %% [markdown]
# We have to convert all test documnets to vectors too as above:

# %%
X_test = []
for i in range(len(test_text)):
    doc_model = np.zeros(100)
    for word in test_text[i+1]:
        if word in train_model.wv.key_to_index:
            doc_model += train_model.wv[word]
        else:
            doc_model += np.zeros(100)
    X_test.append(doc_model/len(train_text[i+1]))

print(len(X_test))
# Out:
# 25000

# %% [markdown]
# # SVM
# This is the time of classification using SVM!
#
# we will do the classification using different parameters to find which combination is the best for this data set.

# %%
svm_classifier = SVC()
svm_classifier.fit(X_train, y_train)

y_pred1 = svm_classifier.predict(X_test)
accuracy1 = svm_classifier.score(X_test, y_test)
print(classification_report(y_test, y_pred1))
print(f"accuracy using default kernel: {accuracy1}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.61      0.66      0.63     12500
#          1.0       0.63      0.58      0.61     12500
#
#     accuracy                           0.62     25000
#    macro avg       0.62      0.62      0.62     25000
# weighted avg       0.62      0.62      0.62     25000
#
# accuracy using default kernel: 0.6212

# %%
svm_classifier_poly_ = SVC(kernel='linear', C=1)
svm_classifier_poly_.fit(X_train, y_train)
y_pred_ = svm_classifier_poly_.predict(X_test)
accuracy_ = svm_classifier_poly_.score(X_test, y_test)
print(classification_report(y_test, y_pred_))
print(f"accuracy using poly kernel: {accuracy_}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.63      0.61     12500
#          1.0       0.60      0.56      0.58     12500
#
#     accuracy                           0.60     25000
#    macro avg       0.60      0.60      0.60     25000
# weighted avg       0.60      0.60      0.60     25000
#
# accuracy using poly kernel: 0.59752

# %% [markdown]
# as it is obvious from the above result, the linear kernel does dot work good for us. Let's consider another kernels.

# %%
svm_classifier_poly1 = SVC(kernel='poly', C=0.1)
svm_classifier_poly1.fit(X_train, y_train)
y_pred2 = svm_classifier_poly1.predict(X_test)
accuracy2 = svm_classifier_poly1.score(X_test, y_test)
print(classification_report(y_test, y_pred2))
print(f"accuracy using poly kernel: {accuracy2}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.71      0.82      0.76     12500
#          1.0       0.78      0.66      0.72     12500
#
#     accuracy                           0.74     25000
#    macro avg       0.74      0.74      0.74     25000
# weighted avg       0.74      0.74      0.74     25000
#
# accuracy using poly kernel: 0.73848

# %%
svm_classifier_poly2 = SVC(kernel='poly', C=0.08)
svm_classifier_poly2.fit(X_train, y_train)
y_pred3 = svm_classifier_poly2.predict(X_test)
accuracy3 = svm_classifier_poly2.score(X_test, y_test)
print(classification_report(y_test, y_pred3))
print(f"accuracy using poly kernel: {accuracy3}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.80      0.78     12500
#          1.0       0.79      0.75      0.77     12500
#
#     accuracy                           0.77     25000
#    macro avg       0.77      0.77      0.77     25000
# weighted avg       0.77      0.77      0.77     25000
#
# accuracy using poly kernel: 0.77316

# %%
svm_classifier_poly2 = SVC(kernel='poly', C=0.08, gamma='auto')
svm_classifier_poly2.fit(X_train, y_train)
y_pred3 = svm_classifier_poly2.predict(X_test)
accuracy3 = svm_classifier_poly2.score(X_test, y_test)
print(classification_report(y_test, y_pred3))
print(f"accuracy using poly kernel: {accuracy3}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.55      0.29      0.38     12500
#          1.0       0.52      0.77      0.62     12500
#
#     accuracy                           0.53     25000
#    macro avg       0.53      0.53      0.50     25000
# weighted avg       0.53      0.53      0.50     25000
#
# accuracy using poly kernel: 0.52664

# %%
svm_classifier_poly3 = SVC(kernel='poly', C=0.09)
svm_classifier_poly3.fit(X_train, y_train)
y_pred4 = svm_classifier_poly3.predict(X_test)
accuracy4= svm_classifier_poly3.score(X_test, y_test)
print(classification_report(y_test, y_pred4))
print(f"accuracy using poly kernel: {accuracy4}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.81      0.76     12500
#          1.0       0.79      0.68      0.73     12500
#
#     accuracy                           0.75     25000
#    macro avg       0.75      0.75      0.75     25000
# weighted avg       0.75      0.75      0.75     25000
#
# accuracy using poly kernel: 0.7494

# %%
svm_classifier_poly4 = SVC(kernel='sigmoid', C=0.1)
svm_classifier_poly4.fit(X_train, y_train)
y_pred4 = svm_classifier_poly4.predict(X_test)
accuracy4 = svm_classifier_poly4.score(X_test, y_test)
print(classification_report(y_test, y_pred4))
print(f"accuracy using poly kernel: {accuracy4}")
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.53      0.76      0.62     12500
#          1.0       0.57      0.32      0.41     12500
#
#     accuracy                           0.54     25000
#    macro avg       0.55      0.54      0.52     25000
# weighted avg       0.55      0.54      0.52     25000
#
# accuracy using poly kernel: 0.53844

# %% [markdown]
# As it is shown above, when we set C=0.08 and the kernel is set on 'poly', we get the best accuracy and f1-score.
# but it is still lower that what we got by Bayes classifier which was near 82.

# %% [markdown]
# # LSA

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
# To do the LSA, we have to first construct our tf-idf matrix 
# and then apply svd and dimention reduction.
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
X_tfidf = tfidf_vectorizer.fit_transform(df['preprocessed'])

# %%
# Apply SVD and dimention reduction
lsa1 = TruncatedSVD(n_components=100)
X_lsa1 = lsa1.fit_transform(X_tfidf)
X_test_lsa1 = lsa1.fit_transform(X_tfidf)

# Train the SVM Classifier
svm_classifier1 = SVC(kernel='linear')

# Initialize and train SVM classifier
svm_classifier1.fit(X_lsa1, y_train)

# Predict labels for test data
y_pred = svm_classifier1.predict(X_test_lsa1)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.80      0.82     12500
#          1.0       0.81      0.85      0.83     12500
#
#     accuracy                           0.83     25000
#    macro avg       0.83      0.83      0.83     25000
# weighted avg       0.83      0.83      0.83     25000

# %%
# Apply SVD and dimention reduction
lsa2 = TruncatedSVD(n_components=300)
X_lsa2 = lsa2.fit_transform(X_tfidf)
X_test_lsa2 = lsa2.fit_transform(X_tfidf)

# Train the SVM Classifier
svm_classifier2 = SVC(kernel='linear')

# Initialize and train SVM classifier
svm_classifier2.fit(X_lsa2, y_train)

# Predict labels for test data
y_pred = svm_classifier2.predict(X_test_lsa2)

# Print classification report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.86      0.83      0.84     12500
#          1.0       0.83      0.87      0.85     12500
#
#     accuracy                           0.85     25000
#    macro avg       0.85      0.85      0.85     25000
# weighted avg       0.85      0.85      0.85     25000

# %% [markdown]
# 2 above cells means that by increasing the number of components, the accuracy increases too!

# %%
# Train the SVM classifier with poly kernel
svm_classifier2 = SVC(kernel='poly')

# Initialize and train SVM classifier
svm_classifier2.fit(X_lsa, y_train)

y_pred = svm_classifier.predict(X_test_lsa)

# Print classification report
print(classification_report(y_test, y_pred))

# %% [markdown]
# As we tested on the dataset, we got 82%, 77%, and 85% accuracy for Bayes classification, W2V and LSA using SVM classifier.
# Thus, as we predicted, the best result on our data was obtaied using SVM on LSA.

# %% [markdown]
# ## FastText
# we just tested another word embedding for fun((:

# %%
from gensim.models import FastText

model2 = FastText(sentences=train_text, vector_size=100, window=5, min_count=1, workers=4, seed=42)

# %%
model2_test = FastText(sentences=test_text, vector_size=100, window=5, min_count=1, workers=4, seed=42)

# %%
X_train2 = []
for i in range(len(train_text)):
    doc_model = np.zeros(100)
    for word in train_text[i+1]:
        doc_model += model2.wv[word]
    X_train2.append(doc_model/len(train_text[i+1]))

# %%
X_test2 = []
for i in range(len(test_text)):
    doc_model = np.zeros(100)
    for word in test_text[i+1]:
        if word in model2.wv.key_to_index:
            doc_model += model2.wv[word]
        else:
            doc_model += np.zeros(100)
    X_test2.append(doc_model/len(train_text[i+1]))

# %%
svm_classifier_poly = SVC(kernel='poly', C=0.1)
svm_classifier_poly.fit(X_train2, y_train)

accuracy_5 = svm_classifier_poly.score(X_test2, y_test)
print(f"accuracy using poly kernel: {accuracy_5}")
# Out:
# accuracy using poly kernel: 0.51344

# %%
svm_classifier_poly = SVC(kernel='poly', C=0.5, gamma=0.1)
svm_classifier_poly.fit(X_train2, y_train)

accuracy_6 = svm_classifier_poly.score(X_test2, y_test)
print(f"accuracy using poly kernel: {accuracy_6}")
# Out:
# accuracy using poly kernel: 0.50516

# %%
svm_classifier_poly = SVC(kernel='poly', C=0.5, gamma=0.01)
svm_classifier_poly.fit(X_train2, y_train)

accuracy_7 = svm_classifier_poly.score(X_test2, y_test)
print(f"accuracy using poly kernel: {accuracy_7}")

# %%
svm_classifier_poly = SVC(kernel='poly', C=0.5, gamma=1)
svm_classifier_poly.fit(X_train2, y_train)

accuracy_8 = svm_classifier_poly.score(X_test2, y_test)
print(f"accuracy using poly kernel: {accuracy_8}")

# %%
test_set['preprocessed'] = test_set['text'].apply(preprocessing)
